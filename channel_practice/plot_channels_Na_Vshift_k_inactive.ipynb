# %%
# %matplotlib inline
from parameters import *
from tau_ch_plot_study import *

# %% [markdown]
# # Na Vshift and k Inactive

# %% [markdown]
# #### STEP-1 Parameters setup

# %%
VSHIFT = 5e-3 
tau = 1
f = 0
gmbar_Na = 120e-3
gmbar_K = 36e-3
K_n_params = get_k_n_params(VSHIFT=0, tau=0, f=0)
Na_h_params = get_na_h_params(VSHIFT=VSHIFT, tau=tau, f=f)
Na_m_params = get_na_m_params(VSHIFT=VSHIFT, tau=tau, f=f)

# %% [markdown]
# #### STEP-2 channel configuration setup

# %%
config_chan = {'na':{'xpower':3, 'ypower':1,
'm_params':Na_m_params, 'h_params':Na_h_params, 'gbar':gmbar_Na, 'ek':115e-3},
'k':{'xpower':4,'ypower':None,
'm_params':K_n_params,'h_params':None,'gbar':gmbar_K, 'ek':-12e-3}}

simtime, simdt, plotdt = 0.1, 02.5e-6, 0.25e-3

# %% [markdown]
# #### STEP-3 Single Compartment neuron creation

# %%
comp = create_1comp_neuron('/model/neuron',1, config_chan)
# Out:
# params(A_A=70.0, A_B=0.0, A_C=0.0, A_D=0.065, A_F=0.02, B_A=1000.0, B_B=0.0, B_C=1.0, B_D=0.03500000000000001, B_F=-0.01, VDIVS=3000, VMIN=-0.1, VMAX=0.04999999999999999)

# %% [markdown]
# #### STEP-4 Stimulus setup and current and voltage tabulation.

# %%
current_tab, vm_tab= setup_stimulation(comp)

# %% [markdown]
# #### STEP-5 MOOSE simulation

# %%
[moose.setClock(i, simdt) for i in range(10)]
moose.setClock(8, plotdt)
moose.reinit()
moose.start(simtime)
ts = np.linspace(0, simtime, len(vm_tab.vector))

# %% [markdown]
# #### STEP-6 Plot Action potentials VS time(s)

# %%
plt.plot(ts, vm_tab.vector * 1e3, label='Vm (mV)')
plt.plot(ts, current_tab.vector * 1e9, label='current (nA)')
plt.legend()
plt.title('Vshift:{:.2E} tau_mul:{:.2E}'.format(VSHIFT, tau) , loc='left')
plt.grid(True)

# %% [markdown]
# Alpha and Beta equations
# - Channel NA -> Inactive and no Vshift added to parameters of  which are impacted by EREST_ACT.
# - Channel K  -> Active and Vshift added to parameters which are impacted by EREST_ACT.

# %%
from moose_nerp.graph.plot_channel import plot_gate_params

# %% [markdown]
# ### window current tiny triangle which is steady state current.

# %%
plot_gate_params(moose.element('/model[0]/na_neuron'), None)

# %%
plot_gate_params(moose.element('/model[0]/k_neuron'), None)
# Out:
# /home/ram/neural_prj/moose_nerp/moose_nerp/graph/plot_channel.py:24: RuntimeWarning: divide by zero encountered in true_divide
#   axes[0].plot(varray, 1e3 / mb, label='mtau ' + chan.name)
# /home/ram/neural_prj/moose_nerp/moose_nerp/graph/plot_channel.py:26: RuntimeWarning: invalid value encountered in true_divide
#   infpow = (ma / mb) ** chan.Xpower
# /home/ram/neural_prj/moose_nerp/moose_nerp/graph/plot_channel.py:28: RuntimeWarning: invalid value encountered in true_divide
#   inf = ma / mb
